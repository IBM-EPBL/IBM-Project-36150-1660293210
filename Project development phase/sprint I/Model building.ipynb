# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"D:\IBM\datasets\Admission prediction.csv")

# %%
df
# Out:
#      10th Score  12th Score  Colaborate  Sports & extra  Clubs   Research  \
# 0           527         198           4             4.5     4.5         1
# 1           514         147           4             4.0     4.5         1
# 2           456         144           3             3.0     3.5         1
# 3           462         190           3             3.5     2.5         1
# 4           454         143           2             2.0     3.0         0
# ..          ...         ...         ...             ...     ...       ...
# 403         453         147           1             2.0     3.0         1
# 404         453         147           2             1.0     2.0         0
# 405         453         147           3             1.0     1.0         0
# 406         453         147           1             1.0     0.0         1
# 407         453         147           3             2.0     3.0         1
#
#      Chance of Admit
# 0                0.92
# 1                0.76
# 2                0.72
# 3                0.80
# 4                0.65
# ..                ...
# 403              0.31
# 404              0.32
# 405              0.33
# 406              0.40
# 407              0.40
#
# [408 rows x 7 columns]

# %% [markdown]
# ## Analyzing the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 408 entries, 0 to 407
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   10th Score        408 non-null    int64
#  1   12th Score        408 non-null    int64
#  2   Colaborate        408 non-null    int64
#  3   Sports & extra    408 non-null    float64
#  4   Clubs             408 non-null    float64
#  5   Research          408 non-null    int64
#  6   Chance of Admit   408 non-null    float64
# dtypes: float64(3), int64(4)
# memory usage: 22.4 KB

# %%
df.corr()
# Out:
#                   10th Score  12th Score  Colaborate  Sports & extra  \
# 10th Score          1.000000    0.690273    0.605586        0.523711
# 12th Score          0.690273    1.000000    0.613050        0.537487
# Colaborate          0.605586    0.613050    1.000000        0.725659
# Sports & extra      0.523711    0.537487    0.725659        1.000000
# Clubs               0.445936    0.464770    0.658351        0.749951
# Research            0.508831    0.407168    0.424274        0.413682
# Chance of Admit     0.665770    0.670492    0.696008        0.696814
#
#                     Clubs   Research  Chance of Admit
# 10th Score        0.445936  0.508831          0.665770
# 12th Score        0.464770  0.407168          0.670492
# Colaborate        0.658351  0.424274          0.696008
# Sports & extra    0.749951  0.413682          0.696814
# Clubs             1.000000  0.380859          0.682286
# Research          0.380859  1.000000          0.501719
# Chance of Admit   0.682286  0.501719          1.000000

# %%
df.describe()
# Out:
#        10th Score  12th Score  Colaborate  Sports & extra      Clubs   \
# count  408.000000  408.000000  408.000000      408.000000  408.000000
# mean   472.073529  162.946078    3.102941        3.377451    3.428922
# std     34.211935   28.315388    1.147239        1.040781    0.944971
# min    358.000000   93.000000    0.000000        0.000000    0.000000
# 25%    452.000000  145.000000    2.000000        2.500000    3.000000
# 50%    456.500000  147.000000    3.000000        3.500000    3.500000
# 75%    515.000000  192.000000    4.000000        4.000000    4.000000
# max    540.000000  200.000000    5.000000        5.000000    5.000000
#
#          Research  Chance of Admit
# count  408.000000        408.000000
# mean     0.561275          0.718309
# std      0.496840          0.150780
# min      0.000000          0.300000
# 25%      0.000000          0.630000
# 50%      1.000000          0.730000
# 75%      1.000000          0.822500
# max      1.000000          1.000000

# %% [markdown]
# ## Handling missing values

# %%
df.isnull().sum()
# Out:
# 10th Score          0
# 12th Score          0
# Colaborate          0
# Sports & extra      0
# Clubs               0
# Research            0
# Chance of Admit     0
# dtype: int64

# %% [markdown]
# ## data visualization

# %%
sns.boxplot(df['12th Score'])
# Out:
# D:\Annaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='12th Score'>

# %%
sns.boxplot(df['10th Score'])
# Out:
# D:\Annaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='10th Score'>

# %%
sns.scatterplot(df['10th Score'],df['12th Score'])
# Out:
# D:\Annaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='10th Score', ylabel='12th Score'>

# %%
sns.distplot(df['12th Score'])
# Out:
# D:\Annaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='12th Score', ylabel='Density'>

# %%
sns.pairplot(df)

# %% [markdown]
# ## split x and y

# %%
y = df.iloc[:,6:]

# %%
y
# Out:
#      Chance of Admit
# 0                0.92
# 1                0.76
# 2                0.72
# 3                0.80
# 4                0.65
# ..                ...
# 403              0.31
# 404              0.32
# 405              0.33
# 406              0.40
# 407              0.40
#
# [408 rows x 1 columns]

# %%
x = df.iloc[:,:6]

# %%
x
# Out:
#      10th Score  12th Score  Colaborate  Sports & extra  Clubs   Research
# 0           527         198           4             4.5     4.5         1
# 1           514         147           4             4.0     4.5         1
# 2           456         144           3             3.0     3.5         1
# 3           462         190           3             3.5     2.5         1
# 4           454         143           2             2.0     3.0         0
# ..          ...         ...         ...             ...     ...       ...
# 403         453         147           1             2.0     3.0         1
# 404         453         147           2             1.0     2.0         0
# 405         453         147           3             1.0     1.0         0
# 406         453         147           1             1.0     0.0         1
# 407         453         147           3             2.0     3.0         1
#
# [408 rows x 6 columns]

# %% [markdown]
# ## scaling

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
sc = StandardScaler()
x_scaled = sc.fit_transform(x)

# %%
x_scaled
# Out:
# array([[ 1.607448  ,  1.23950124,  0.78288815,  1.07988838,  1.13484293,
#          0.88411503],
#        [ 1.22699712, -0.56385087,  0.78288815,  0.59889006,  1.13484293,
#          0.88411503],
#        [-0.47039911, -0.6699304 , -0.08983962, -0.36310657,  0.07530994,
#          0.88411503],
#        ...,
#        [-0.55819546, -0.56385087, -0.08983962, -2.28709984, -2.57352252,
#         -1.13107454],
#        [-0.55819546, -0.56385087, -1.83529517, -2.28709984, -3.6330555 ,
#          0.88411503],
#        [-0.55819546, -0.56385087, -0.08983962, -1.32510321, -0.45445655,
#          0.88411503]])

# %% [markdown]
# y.value_counts()

# %% [markdown]
# ## train and test

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_scaled,y,random_state=2)

# %%
x_train.shape
# Out:
# (306, 6)

# %%
x_test.shape
# Out:
# (102, 6)

# %%
y_train.shape
# Out:
# (306, 1)

# %%
y_test.shape
# Out:
# (102, 1)

# %% [markdown]
# ## build a model

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
p = lr.predict(x_test)
p
# Out:
# array([[0.86432933],
#        [0.85652701],
#        [0.46146263],
#        [0.916296  ],
#        [0.87148017],
#        [0.54762276],
#        [0.58789127],
#        [0.93896245],
#        [0.53374514],
#        [0.77721699],
#        [0.68260174],
#        [0.94689388],
#        [0.93727386],
#        [0.62365163],
#        [0.68720115],
#        [0.92478677],
#        [0.53700773],
#        [0.94776123],
#        [0.62538485],
#        [0.76611592],
#        [0.66803715],
#        [0.91729933],
#        [0.7867476 ],
#        [0.61861818],
#        [0.6274252 ],
#        [0.6145963 ],
#        [0.70966003],
#        [0.79160067],
#        [0.72785161],
#        [0.56440122],
#        [0.6520415 ],
#        [0.71151927],
#        [0.49469576],
#        [0.68343058],
#        [0.92314194],
#        [0.75117784],
#        [0.69877786],
#        [0.63540587],
#        [0.91851086],
#        [0.86553785],
#        [0.62946343],
#        [0.63400849],
#        [0.57774897],
#        [0.8776339 ],
#        [0.76728417],
#        [0.89748999],
#        [0.64619057],
#        [0.45829527],
#        [0.58728893],
#        [0.76533459],
#        [0.6666996 ],
#        [0.77395934],
#        [0.50186104],
#        [0.80410549],
#        [0.72041241],
#        [0.7292036 ],
#        [0.66352837],
#        [0.64789359],
#        [0.6734134 ],
#        [0.75814597],
#        [0.74470786],
#        [0.71281382],
#        [0.53939089],
#        [0.68455298],
#        [0.47607424],
#        [0.52097892],
#        [0.51216194],
#        [0.94455684],
#        [0.57922151],
#        [0.8438532 ],
#        [0.77077652],
#        [0.8275716 ],
#        [0.53076724],
#        [0.78618142],
#        [0.66959983],
#        [0.61004138],
#        [0.93294395],
#        [0.69057457],
#        [0.64476388],
#        [0.79075489],
#        [0.64823028],
#        [0.61616035],
#        [0.73300695],
#        [0.87222149],
#        [0.65010161],
#        [0.60336385],
#        [0.7888681 ],
#        [0.65200834],
#        [0.59513809],
#        [0.61815171],
#        [0.70522967],
#        [0.80194059],
#        [0.72000245],
#        [0.72460186],
#        [0.71559935],
#        [0.73810987],
#        [0.7034481 ],
#        [0.71575291],
#        [0.59595697],
#        [0.80427763],
#        [0.71736188],
#        [0.86961644]])

# %% [markdown]
# ## model evaluation

# %%
from sklearn.metrics import r2_score
r2_score(p,y_test)
# Out:
# 0.6826630902418438

# %% [markdown]
# ## Save the model

# %%
import pickle
pickle.dump(lr,open('D:\IBM\model\Saved model.pkl','wb'))
